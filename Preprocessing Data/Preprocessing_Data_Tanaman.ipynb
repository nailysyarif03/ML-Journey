# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

# %%
from google.colab import files
uploades = files.upload()
# Out:
#      <input type="file" id="files-bdf44281-1d0d-4243-bc6a-da4bc3359ed3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bdf44281-1d0d-4243-bc6a-da4bc3359ed3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_plant = pd.read_csv('Data Rekomendasi Tanaman Fix.csv')
df_plant.head(5)
# Out:
#    No  Tanah Humus       Aluvial       Vulkanik        Gambut          Liat  \
# 0   1        Bayam  Bawang merah  Bawang Bombay        Bungur         Aster
# 1   2        Cabai  Bawang Putih   Bawang Merah         Cabai  Bunga Bakung
# 2   3  Daun Bawang         Cabai   Bawang Putih        Jagung    Bunga Lili
# 3   4       Jagung        Dahlia      Bengkuang  Kacang Tanah    Coneflower
# 4   5         Jahe        Jagung          Cabai       Kedelai     Cup Plant
#
#         Kapur     Litosol    Organosol      Regosol         Pasir   Laterit
# 0        Apel       Cabai        Bayam      Alpukat  Bawang Merah  Aglonema
# 1        Dril     Cokelat  Daun Bawang      Anggur   Bawang Putih   Cengkeh
# 2     Granado  Jambu Mete       Jagung         Apel           Bit   Cokelat
# 3  Grapefruit       Karet       Jagung         Apel     Buah Naga    Durian
# 4      Jagung      Kelapa         Jahe  Bougenville  Bunga Katang     Jambu

# %%
df_plant.tail()
# Out:
#     No Tanah Humus   Aluvial   Vulkanik           Gambut           Liat  \
# 15  16        Sawi     Serai      Talas  Pohon Terentang    Sage Russia
# 16  17      Selada      Tebu   Tembakau    Tanaman Punak       Stroberi
# 17  18        Tebu  Tembakau     Terong         Singkong    Switchgrass
# 18  19       Timun     Tomat  Ubi Jalar            Tomat  Tanaman Lilac
# 19  20       Tomat    Wortel     Wortel        Ubi Jalar   Teki Tahunan
#
#            Kapur    Litosol   Organosol   Regosol            Pasir   Laterit
# 15        Pisang      Talas  Sawi Putih     Palem            Pakis  Singkong
# 16  Prem Higuera       Tebu    Singkong       Pir  Peperomia Hijau    Sorgum
# 17      Singkong     Terong    Tembakau  Tembakau         Singkong     Talas
# 18     Ubi Jalar  Ubi Jalar       Timun    Terong     Tanaman Giok      Tebu
# 19        Wortel     Wortel   Ubi Jalar     Tomat           Wortel    Wortel

# %%
df_plant.dtypes
# Out:
# No              int64
# Tanah Humus    object
# Aluvial        object
# Vulkanik       object
# Gambut         object
# Liat           object
# Kapur          object
# Litosol        object
# Organosol      object
# Regosol        object
# Pasir          object
# Laterit        object
# dtype: object

# %%
df_plant.describe().transpose()
# Out:
#     count  mean      std  min   25%   50%    75%   max
# No   20.0  10.5  5.91608  1.0  5.75  10.5  15.25  20.0

# %%
df_plant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   No           20 non-null     int64
#  1   Tanah Humus  20 non-null     object
#  2   Aluvial      20 non-null     object
#  3   Vulkanik     20 non-null     object
#  4   Gambut       20 non-null     object
#  5   Liat         20 non-null     object
#  6   Kapur        20 non-null     object
#  7   Litosol      20 non-null     object
#  8   Organosol    20 non-null     object
#  9   Regosol      20 non-null     object
#  10  Pasir        20 non-null     object
#  11  Laterit      20 non-null     object
# dtypes: int64(1), object(11)
# memory usage: 2.0+ KB

# %%
def drop_data():
  print("Proses drop kolom yang tidak diperlukan")
  global df_plant
  df_plant = df_plant.drop(columns=['1'])
  time.sleep(10)
  print("Drop Berhasil")
  time.sleep(5)
  print("Drop Selesai")

# %%
df_plant
# Out:
#     No     Tanah Humus       Aluvial       Vulkanik           Gambut  \
# 0    1           Bayam  Bawang merah  Bawang Bombay           Bungur
# 1    2           Cabai  Bawang Putih   Bawang Merah            Cabai
# 2    3     Daun Bawang         Cabai   Bawang Putih           Jagung
# 3    4          Jagung        Dahlia      Bengkuang     Kacang Tanah
# 4    5            Jahe        Jagung          Cabai          Kedelai
# 5    6         Jeruk            Jahe          Karet     Kelapa Sawit
# 6    7     Jeruk Nipis   Jeruk Nipis         Kelapa            Melon
# 7    8  Kacang Panjang        Kelapa        Kentang         Mentimun
# 8    9        Kangkung        Kunyit         Ketela     Meranti Rawa
# 9   10          Kelapa        Mangga           Kopi            Nanas
# 10  11          Kunyit         Mawar          Kubis             Pare
# 11  12          Mangga        Melati          Lobak           Pepaya
# 12  13           Melon         Melon           Padi           Pisang
# ...

# %%
fig = sns.displot(df_plant['Tanah Humus'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#cek missing value tapi sebenernya gada valuenya sih jadi yaudah gapapa hehe
total = df_plant.isnull().sum().sort_values(ascending = False)
print(total)
# Out:
# No             0
# Tanah Humus    0
# Aluvial        0
# Vulkanik       0
# Gambut         0
# Liat           0
# Kapur          0
# Litosol        0
# Organosol      0
# Regosol        0
# Pasir          0
# Laterit        0
# dtype: int64
